# %%
import tweepy
from pprint import pprint
import pandas as pd

pd.options.display.max_rows = 100

# %%
TWITTER_APP_KEY = 'RNbWRckUdr1mzMYe2ir2S44aP'
TWITTER_APP_SECRET = 'FVB0RX0nGo1VMRAMF603g7jOKuZdKfCLo0SjXWv2T15wHvLMRy'
TWITTER_KEY = '1220749681900191744-JDImKJjEF4NadKsiKekx82zDI9FyQW'
TWITTER_SECRET = 'bQaUWESSjNkqhO3d2Sc4pLPmNDYLr5DiRIIS5ko5Sg4yv'

auth = tweepy.OAuthHandler(TWITTER_APP_KEY, TWITTER_APP_SECRET)
auth.set_access_token(TWITTER_KEY, TWITTER_SECRET)

api = tweepy.API(auth)

# class StreamListener(tweepy.StreamListener):
#     def on_status(self, status):
#         print(status.text)
l = []
class StreamListener(tweepy.StreamListener):
    def on_status(self, status):
#         pprint(status._json)
        print (status.entities)
        #spark.createDataFrame([(status.user.id_str, status.user.name, status.text, status.geo,status.user.location,status.user.followers_count,status.user.created_at,status.user.statuses_count)]
                              #,["user_id", "user_name" ,"text","location","user_location","user_followers_count","user_created_at","user_count_tweets"],schema=schema).write.csv("twitter_data",mode='append')  
        
        
#         data = (status.user.id_str, status.user.name, status.text, 
#                                 status.geo,status.user.location,status.user.followers_count,
#                                 status.user.created_at,status.user.statuses_count,[text['text'] for text in status.entities['hashtags']])
        for text in status.entities['hashtags']:
            data = (status.user.id_str, status.user.name, status.text, 
                                status.geo,status.user.location,status.user.followers_count,
                                status.user.created_at,status.user.statuses_count,text['text'])
            spark.createDataFrame([(data)],schema=schema).write.csv("twitter_data",mode='append')
        
    def on_error(self, status_code):
        if status_code == 420:
            return False

stream_listener = StreamListener()
stream = tweepy.Stream(auth=api.auth, listener=stream_listener)

# %%
stream.filter(track=["#trump", "#clinton", "#hillaryclinton", "#donaldtrump"])
# stream.filter()
# Out:
# {'hashtags': [], 'urls': [], 'user_mentions': [{'screen_name': 'AndyOstroy', 'name': 'Andy Ostroy', 'id': 123281100, 'id_str': '123281100', 'indices': [3, 14]}, {'screen_name': 'realDonaldTrump', 'name': 'Donald J. Trump', 'id': 25073877, 'id_str': '25073877', 'indices': [21, 37]}], 'symbols': []}
# {'hashtags': [], 'urls': [{'url': 'https://t.co/piDWGNhmYN', 'expanded_url': 'https://twitter.com/i/web/status/1225484372717002753', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [114, 137]}], 'user_mentions': [{'screen_name': 'NPR', 'name': 'NPR', 'id': 5392522, 'id_str': '5392522', 'indices': [0, 4]}], 'symbols': []}
# {'hashtags': [], 'urls': [], 'user_mentions': [{'screen_name': 'wowisme4159', 'name': 'Oregon Coast', 'id': 705921327752806401, 'id_str': '705921327752806401', 'indices': [3, 15]}], 'symbols': []}
# {'hashtags': [{'text': 'Trump', 'indices': [31, 37]}], 'urls': [], 'user_mentions': [], 'symbols': []}
# {'hashtags': [], 'urls': [], 'user_mentions': [{'screen_name': 'AndyOstroy', 'name': 'Andy Ostroy', 'id': 123281100, 'id_str': '123281100', 'indices': [3, 14]}], 'symbols': []}
# {'hashtags': [{'text': 'Trump', 'indices': [14, 20]}, {'text': 'NotMyPresident', 'indices': [21, 36]}], 'urls': [{'url': 'https://t.co/niMEvmFddw', 'expanded_url': 'https://twitter.com/i/web/status/1225484379205533696', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [121, 144]}], 'user_mentions': [], 'symbols': []}
# {'hashtags': [{'text': 'Trump', 'indices': [40, 46]}], 'urls': [], 'user_mentions': [{'screen_name': 'RoaJavier', 'name': 'Javier Alexander Roa', 'id': 140463683, 'id_str': '140463683', 'indices': [3, 13]}], 'symbols': []}
# {'hashtags': [], 'urls': [], 'user_mentions': [{'screen_name': 'Therealbp65', 'name': 'America The Beautiful', 'id': 802042941959045120, 'id_str': '802042941959045120', 'indices': [3, 15]}], 'symbols': []}
# {'hashtags': [{'text': 'Trump', 'indices': [115, 121]}], 'urls': [], 'user_mentions': [{'screen_name': 'AndyOstroy', 'name': 'Andy Ostroy', 'id': 123281100, 'id_str': '123281100', 'indices': [3, 14]}], 'symbols': []}
# {'hashtags': [], 'urls': [], 'user_mentions': [{'screen_name': 'AndyOstroy', 'name': 'Andy Ostroy', 'id': 123281100, 'id_str': '123281100', 'indices': [3, 14]}], 'symbols': []}
# {'hashtags': [{'text': 'Trump', 'indices': [20, 26]}], 'urls': [], 'user_mentions': [], 'symbols': []}
# {'hashtags': [{'text': 'medaloffreedom', 'indices': [10, 25]}, {'text': 'Racist', 'indices': [66, 73]}, {'text': 'Sexist', 'indices': [75, 82]}, {'text': 'Bigot', 'indices': [83, 89]}, {'text': 'Pig', 'indices': [96, 100]}], 'urls': [{'url': 'https://t.co/0SU3kv1IkX', 'expanded_url': 'https://twitter.com/i/web/status/1225484394141540352', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [109, 132]}], 'user_mentions': [{'screen_name': 'JoeBiden', 'name': 'Joe Biden (Text Join to 30330)', 'id': 939091, 'id_str': '939091', 'indices': [0, 9]}], 'symbols': []}
# {'hashtags': [{'text': 'Trump', 'indices': [10, 16]}, {'text': 'Trump2020Victory', 'indices': [97, 114]}], 'urls': [], 'user_mentions': [], 'symbols': []}
# {'hashtags': [{'text': 'Trump', 'indices': [74, 80]}, {'text': 'MittRomney', 'indices': [81, 92]}, {'text': 'ImpeachmentSham', 'indices': [93, 109]}], 'urls': [], 'user_mentions': [{'screen_name': 'AndyOstroy', 'name': 'Andy Ostroy', 'id': 123281100, 'id_str': '123281100', 'indices': [3, 14]}, {'screen_name': 'realDonaldTrump', 'name': 'Donald J. Trump', 'id': 25073877, 'id_str': '25073877', 'indices': [16, 32]}, {'screen_name': 'MittRomney', 'name': 'Mitt Romney', 'id': 50055701, 'id_str': '50055701', 'indices': [33, 44]}], 'symbols': []}
# {'hashtags': [{'text': 'trump', 'indices': [22, 28]}], 'urls': [], 'user_mentions': [{'screen_name': 'FDRLST', 'name': 'The Federalist', 'id': 1408003598, 'id_str': '1408003598', 'indices': [0, 7]}], 'symbols': []}
# {'hashtags': [{'text': 'trump', 'indices': [16, 22]}, {'text': 'VoteBlueToEndThisNightmare', 'indices': [48, 75]}], 'urls': [], 'user_mentions': [{'screen_name': 'portside27', 'name': 'Jan Lewis', 'id': 324145805, 'id_str': '324145805', 'indices': [3, 14]}], 'symbols': []}
# {'hashtags': [{'text': 'Trump', 'indices': [30, 36]}], 'urls': [{'url': 'https://t.co/WFnkTHD5aq', 'expanded_url': 'https://www.anti-spiegel.ru/2020/amtsenthbungsverfahren-gegen-trump-beendet-desinformation-im-spiegel-geht-weiter/', 'display_url': 'anti-spiegel.ru/2020/amtsenthb…', 'indices': [85, 108]}], 'user_mentions': [], 'symbols': []}
# {'hashtags': [], 'urls': [], 'user_mentions': [], 'symbols': []}
# {'hashtags': [], 'urls': [], 'user_mentions': [{'screen_name': 'JohnELTenney', 'name': 'John E.L. Tenney', 'id': 89543485, 'id_str': '89543485', 'indices': [3, 16]}], 'symbols': []}
# {'hashtags': [{'text': 'kkkcult', 'indices': [47, 55]}, {'text': 'Cult45', 'indices': [91, 98]}, {'text': 'mentalhealth', 'indices': [100, 113]}], 'urls': [{'url': 'https://t.co/ffjRNP7Tec', 'expanded_url': 'https://twitter.com/i/web/status/1225484424382472192', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [115, 138]}], 'user_mentions': [], 'symbols': []}
# {'hashtags': [], 'urls': [], 'user_mentions': [{'screen_name': 'GWGoldnadel', 'name': 'G-William Goldnadel', 'id': 3373762791, 'id_str': '3373762791', 'indices': [3, 15]}], 'symbols': []}
# {'hashtags': [], 'urls': [], 'user_mentions': [{'screen_name': 'AndyOstroy', 'name': 'Andy Ostroy', 'id': 123281100, 'id_str': '123281100', 'indices': [3, 14]}], 'symbols': []}
# {'hashtags': [{'text': 'EEUU', 'indices': [35, 40]}, {'text': 'Trump', 'indices': [52, 58]}, {'text': 'impeachment', 'indices': [117, 129]}], 'urls': [], 'user_mentions': [{'screen_name': 'ReutersLatam', 'name': 'Reuters Latam', 'id': 201867844, 'id_str': '201867844', 'indices': [3, 16]}], 'symbols': []}
# {'hashtags': [{'text': 'Trump', 'indices': [8, 14]}], 'urls': [], 'user_mentions': [{'screen_name': 'POTUS', 'name': 'President Trump', 'id': 822215679726100480, 'id_str': '822215679726100480', 'indices': [1, 7]}], 'symbols': []}
# {'hashtags': [{'text': 'EEUU', 'indices': [19, 24]}, {'text': 'Trumpspeech', 'indices': [33, 45]}, {'text': 'Trump', 'indices': [79, 85]}], 'urls': [], 'user_mentions': [{'screen_name': 'ElCuervoNica', 'name': '🅴🅻 🅲🆄🅴🆁🆅🅾🇳🇮', 'id': 1002220095878418432, 'id_str': '1002220095878418432', 'indices': [3, 16]}], 'symbols': []}
# {'hashtags': [{'text': 'Satan', 'indices': [65, 71]}, {'text': 'Politics', 'indices': [72, 81]}, {'text': 'Trump', 'indices': [82, 88]}, {'text': 'DNC', 'indices': [89, 93]}], 'urls': [], 'user_mentions': [], 'symbols': [], 'media': [{'id': 1225484437762256897, 'id_str': '1225484437762256897', 'indices': [94, 117], 'media_url': 'http://pbs.twimg.com/media/EQHLmm6WsAEoc1m.jpg', 'media_url_https': 'https://pbs.twimg.com/media/E
}], 'symbols': []}
# {'hashtags': [{'text': 'Trump2020Landslide', 'indices': [96, 115]}, {'text': 'Trump', 'indices': [116, 122]}, {'text': 'PelosiMeltdown', 'indices': [123, 138]}], 'urls': [{'url': 'https://t.co/WPZEz1EnZr', 'expanded_url': 'https://comicallyincorrect.com/a-f-branco-cartoon-trump-derangement-syndrome/', 'display_url': 'comicallyincorrect.com/a-f-branco-car…', 'indices': [58, 81]}], 'user_mentions': [{'screen_name': 'afbranco', 'name': 'A.F. Branco Cartoons', 'id': 98956941, 'id_str': '98956941', 'indices': [3, 12]}, {'screen_name': 'afbranco', 'name': 'A.F. Branco Cartoons', 'id': 98956941, 'id_str': '98956941', 'indices': [86, 95]}], 'symbols': []}
# {'hashtags': [{'text': 'Trump', 'indices': [16, 22]}], 'urls': [], 'user_mentions': [{'screen_name': 'CoyotyDave', 'name': 'Coyoty', 'id': 26350776, 'id_str': '26350776', 'indices': [3, 14]}], 'symbols': []}
# {'hashtags': [{'text': 'Benghazi', 'indices': [64, 73]}, {'text': 'HillaryClinton', 'indices': [76, 91]}, {'text': 'GrandmaDeath', 'indices': [92, 105]}, {'text': 'killery', 'indices': [106, 114]}], 'urls': [], 'user_mentions': [{'screen_name': 'Harrisjscott', 'name': 'J Scott Harris - Home Mortgage Expert, Ask me Q?s', 'id': 82647883, 'id_str': '82647883', 'indices': [3, 16]}, {'screen_name': 'HillaryClinton', 'name': 'Hillary Clinton', 'id': 1339835893, 'id_str': '1339835893', 'indices': [115, 130]}], 'symbols': []}
# {'hashtags': [{'text': 'Trump', 'indices': [94, 100]}, {'text': 'TrumpImpeachment', 'indices': [101, 118]}], 'urls': [], 'user_mentions': [{'screen_name': 'US_Awake', 'name': 'ConcernedCitizen', 'id': 804911496971087872, 'id_str': '804911496971087872', 'indices': [3, 12]}], 'symbols': []}
# {'hashtags': [{'text': 'ToddHerman', 'indices': [22, 33]}, {'text': 'RushLimbaugh', 'indices': [48, 61]}, {'text': 'PaulRyan', 'indices': [68, 77]}], 'urls': [], 'user_mentions': [{'screen_name': 'SigBeretta', 'name': 'TMoss™🇺🇸⭐️⭐️⭐️', 'id': 961363650, 'id_str': '961363650', 'indices': [3, 14]}], 'symbols': []}
# {'hashtags': [{'text': 'trump', 'indices': [0, 6]}], 'urls': [], 'user_mentions': [], 'symbols': []}
# {'hashtags': [{'text': 'DonaldTrump', 'indices': [120, 132]}], 'urls': [], 'user_mentions': [{'screen_name': 'TheView', 'name': 'The View', 'id': 21258337, 'id_str': '21258337', 'indices': [0, 8]}, {'screen_name': 'PeteButtigieg', 'name': 'Pete Buttigieg', 'id': 226222147, 'id_str': '226222147', 'indices': [9, 23]}], 'symbols': []}
# {'hashtags': [], 'urls': [], 'user_mentions': [{'screen_name': 'AndyOstroy', 'name': 'Andy Ostroy', 'id': 123281100, 'id_str': '123281100', 'indices': [3, 14]}], 'symbols': []}
# {'hashtags': [], 'urls': [], 'user_mentions': [{'screen_name': 'scottycknight', 'name': 'Scotty Christopher Knight', 'id': 627991841, 'id_str': '627991841', 'indices': [3, 17]}], 'symbols': []}
# {'hashtags': [{'text': 'Trump', 'indices': [0, 6]}, {'text': 'Russia', 'indices': [17, 24]}, {'text': 'bulls', 'indices': [40, 46]}], 'urls': [{'url': 'https://t.co/zIg0oQApnp', 'expanded_url': 'https://thehill.com/homenews/administration/481852-trump-calls-the-russia-investigation-bulls', 'display_url': 'thehill.com/homenews/admin…', 'indices': [51, 74]}], 'user_mentions': [], 'symbols': []}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-b8fe09bf7e73> in <module>
# ----> 1 stream.filter(track=["#trump", "#clinton", "#hillaryclinton", "#donaldtrump"])
#       2 # stream.filter()
#
# ~/BigData/venv/lib/python3.7/site-packages/tweepy/streaming.py in filter(self, follow, track, is_async, locations, stall_warnings, languages, encoding, filter_level)
#     472             self.body['filter_level'] = filter_level.encode(encoding)
#     473         self.session.params = {'delimited': 'length'}
# --> 474         self._start(is_async)
#     475
#     476     def sitestream(self, follow, stall_warnings=False,
#
# ~/BigData/venv/lib/python3.7/site-packages/tweepy/streaming.py in _start(self, is_async)
#     387             self._thread.start()
#     388         else:
# --> 389             self._run()
#     390
#     391     def on_closed(self, resp):
#
# ~/BigData/venv/lib/python3.7/site-packages/tweepy/streaming.py in _run(self)
#     287                     self.snooze_time = self.snooze_time_step
#     288                     self.listener.on_connect()
# --> 289                     self._read_loop(resp)
#     290             except (Timeout, ssl.SSLError) as exc:
#     291                 # This is still necessary, as a SSLError can actually be
#
# ~/BigData/venv/lib/python3.7/site-packages/tweepy/streaming.py in _read_loop(self, resp)
#     337             length = 0
#     338             while not resp.raw.closed:
# --> 339                 line = buf.read_line()
#     340                 stripped_line = line.strip() if line else line # line is sometimes None so we need to check here
#     341                 if not stripped_line:
#
# ~/BigData/venv/lib/python3.7/site-packages/tweepy/streaming.py in read_line(self, sep)
#     198             else:
#     199                 start = len(self._buffer)
# --> 200             self._buffer += self._stream.read(self._chunk_size)
#     201         return six.b('')
#     202
#
# ~/BigData/venv/lib/python3.7/site-packages/urllib3/response.py in read(self, amt, decode_content, cache_content)
#     505             else:
#     506                 cache_content = False
# --> 507                 data = self._fp.read(amt) if not fp_closed else b""
#     508                 if (
#     509                     amt != 0 and not data
#
# /usr/local/Cellar/python/3.7.4_1/Frameworks/Python.framework/Versions/3.7/lib/python3.7/http/client.py in read(self, amt)
#     455             # Amount is given, implement using readinto
#     456             b = bytearray(amt)
# --> 457             n = self.readinto(b)
#     458             return memoryview(b)[:n].tobytes()
#     459         else:
#
# /usr/local/Cellar/python/3.7.4_1/Frameworks/Python.framework/Versions/3.7/lib/python3.7/http/client.py in readinto(self, b)
#     489
#     490         if self.chunked:
# --> 491             return self._readinto_chunked(b)
#     492
#     493         if self.length is not None:
#
# /usr/local/Cellar/python/3.7.4_1/Frameworks/Python.framework/Versions/3.7/lib/python3.7/http/client.py in _readinto_chunked(self, b)
#     584         try:
#     585             while True:
# --> 586                 chunk_left = self._get_chunk_left()
#     587                 if chunk_left is None:
#     588                     return total_bytes
#
# /usr/local/Cellar/python/3.7.4_1/Frameworks/Python.framework/Versions/3.7/lib/python3.7/http/client.py in _get_chunk_left(self)
#     552                 self._safe_read(2)  # toss the CRLF at the end of the chunk
#     553             try:
# --> 554                 chunk_left = self._read_next_chunk_size()
#     555             except ValueError:
#     556                 raise IncompleteRead(b'')
#
# /usr/local/Cellar/python/3.7.4_1/Frameworks/Python.framework/Versions/3.7/lib/python3.7/http/client.py in _read_next_chunk_size(self)
#     512     def _read_next_chunk_size(self):
#     513         # Read the next chunk size from the file
# --> 514         line = self.fp.readline(_MAXLINE + 1)
#     515         if len(line) > _MAXLINE:
#     516             raise LineTooLong("chunk size")
#
# /usr/local/Cellar/python/3.7.4_1/Frameworks/Python.framework/Versions/3.7/lib/python3.7/socket.py in readinto(self, b)
#     587         while True:
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#     591                 self._timeout_occurred = True
#
# /usr/local/Cellar/python/3.7.4_1/Frameworks/Python.framework/Versions/3.7/lib/python3.7/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1069                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1070                   self.__class__)
# -> 1071             return self.read(nbytes, buffer)
#    1072         else:
#    1073             return super().recv_into(buffer, nbytes, flags)
#
# /usr/local/Cellar/python/3.7.4_1/Frameworks/Python.framework/Versions/3.7/lib/python3.7/ssl.py in read(self, len, buffer)
#     927         try:
#     928             if buffer is not None:
# --> 929                 return self._sslobj.read(len, buffer)
#     930             else:
#     931                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
len(l)
# Out:
# 0

# %%
l[0][]
# Out:
#   File "<ipython-input-41-c3ca90398118>", line 1
#     l[0][]
#          ^
# SyntaxError: invalid syntax

# %%
l[0]['retweet_count']
# Out:
# 0

# %%
#Creacion SparkSession

from pyspark.sql import SparkSession
spark=SparkSession.builder.appName('twitter_structured_streaming').getOrCreate()
# Librerias 

import pyspark.sql.functions as F
from pyspark.sql.types import *

# %%
spark.__dict__.keys()
# Out:
# dict_keys(['_sc', '_jsc', '_jvm', '_jsparkSession', '_jwrapped', '_wrapped'])

# %%
#define schema para el input data
schema=StructType().add("user_id", "string")\
.add("user_name", "string").add("text", "string")\
.add("location", "string").add("user_location","string")\
.add("user_followers_count","integer").add("user_created_at",'string')\
.add("user_count_tweets","integer").add("hashtag",'string')
schema
# Out:
# StructType(List(StructField(user_id,StringType,true),StructField(user_name,StringType,true),StructField(text,StringType,true),StructField(location,StringType,true),StructField(user_location,StringType,true),StructField(user_followers_count,IntegerType,true),StructField(user_created_at,StringType,true),StructField(user_count_tweets,IntegerType,true),StructField(hashtag,StringType,true)))

# %%
df_2=spark.createDataFrame([("XN203",'user',"#prueba","loc","he",100,"hoy",20,6000,500)], 
["user_id", "user_name" ,"text","location","user_location","user_followers_count",
"user_created_at","user_count_tweets"]).write.csv("twitter_data",mode='append')

# %%
data=spark.readStream.option("sep", ",").schema(schema).csv("twitter_data")

# %%
data.printSchema()
# Out:
# root
#  |-- user_id: string (nullable = true)
#  |-- user_name: string (nullable = true)
#  |-- text: string (nullable = true)
#  |-- location: string (nullable = true)
#  |-- user_location: string (nullable = true)
#  |-- user_followers_count: integer (nullable = true)
#  |-- user_created_at: string (nullable = true)
#  |-- user_count_tweets: integer (nullable = true)
#  |-- hashtag: string (nullable = true)

# %%
count = data.groupBy("user_name").count()
query = (count.writeStream.queryName('count_query').outputMode('complete').format('memory').start())
# spark.sql("select * from count_query").toPandas().head()

# %%
spark.sql("select * from count_query").toPandas()
# Out:
#                                             user_name  count
# 0                                                 Rod      1
# 1                                         Puck Arks ⏳      4
# 2                                          𝙼𝚒𝚔𝚎 𝙱𝚛𝚊𝚗𝚍      1
# 3                                            Hermione      1
# 4                                      Chevalier Noir      1
# 5                                     Mark Bahrenfuss      1
# 6                                Jacqueline Reisinger      3
# 7                                          Gina Eaton      3
# 8                                          Yoda 14120      1
# 9                                     Sukie...🌹IM🍑ED!      1
# 10                                       Gary Derrick      1
# 11                                          Emchilles      1
# 12                                         Juan Lopez      3
# 13                                        bret israel      1
# 14                                               Atze      1
# 15                                               None     49
# 16                                   Science|Business      1
# 17                                   mitchell johnson      3
# 18               CINCERON         (Irreverente 1000%)      1
# 19                                        The Curator      3
# 20                                      U.S. Route 41      2
# 21                                   Kemurphy@shaw.ca      1
# 22                                     sharnettereese      1
# 23                                  Mike McIntire Jr.      1
# 24                                      WeAreAll24601      1
# 25                                     Tatiana Wright      1
# 26                                   Dad Jokes by Dad      1
# 27                                           Sam Iwen      2
# 28                                El-Varel Baby Saleh      1
# 29                                             Brenda      3
# 30                                 ProudAmerican🇺🇸Sue      1
# 31                                    Trump Retweeter      6
# 32                                       hhamberg 🌊🌊🌊      1
# 33                                         Eddie Graf      1
# 34                                      AɗυƖт ƁяαzιƖ™      6
# 35                                         Triston212      1
# 36                                        Chuck Flynn      2
# 37                                      Lori Severson      1
# 38                                        Kaleo James      1
# 39                                       Alana Austin      1
# 40                                               Troy      4
# 41                                   Daily News Egypt      1
# 42                                   BeckyDridenDress      1
# 43                               𝕶𝖓𝖎𝖌𝖍𝖙𝖘 𝖔𝖋 𝕮𝖍𝖗𝖎𝖘𝖙       1
# 44                                            Ryk Gye      1
# 45                               Nicolas Sanchez O'D.      1
# 46                                            Frankie      1
# 47                                Paula T. Hradkowsky      2
# 48                                              oxefe      2
# 49                                        Raúl Tobias      1
# 50             Donald J Trump is impeached!! 💃🏽🙏🏼🙌🏼 🍾      1
# 51                                            atticvs      2
# 52                          Juan-Carlos François 🇯🇲🇱🇨      1
# 53                                              M🌊🌊🌊🌊      1
# 54                                    Denteh Nicholas      1
# 55                                           Suec 🇺🇸🌎      5
# 56                                              mar𓂀o      1
# 57   racista y con desprecio dejando con la mano e...      1
# 58                               Trading MarcoDaCosta      3

# %%
# data.show().writeStream.queryName('count_query').outputMode('complete').format('memory').start()
d = data.filter(data['user_name']!='None')
d = d.groupBy(["hashtag","user_name"]).count()
# d = data.describe(['user_followers_count']).show()
query_2 = d.writeStream.queryName('pruebaa').outputMode('complete').format('memory').start()
# d= data.writeStream.format('console').start()

# %%
df= spark.sql("select * from pruebaa").toPandas()

# %%
df
# Out:
#                                          hashtag  \
# 0                                          Trump
# 1                                            DNC
# 2                                          trump
# 3                                   mentalhealth
# 4                                         Cult45
# 5                                          Trump
# 6                                           None
# 7                                 medaloffreedom
# 8                                  [UNSC, Trump]
# 9                                          Trump
# 10                                            []
# 11                                            []
# 12                                    MittRomney
# 13                                        Russia
# 14                                    ToddHerman
# 15                                          None
# 16                                NotMyPresident
# 17         [Bullshit, Trump, RussiaRussiaRussia]
# 18                                        Sexist
# 19                                         Trump
# 20                                         Trump
# 21                                          None
# 22                                       [Trump]
# 23                            Trump2020Landslide
# 24                                            []
# 25                                       [Trump]
# 26                                          None
# 27                                   impeachment
# 28                                         Trump
# 29                                   SenateTrial
# 30                                          sham
# 31                                         trump
# 32                                   DonaldTrump
# 33                                         Trump
# 34                                          None
# 35                                          None
# 36                               ImpeachmentSham
# 37                                         Trump
# 38                                      PaulRyan
# 39                                Impeached4Life
# 40                                            []
# 41                                          None
# 42                                       [Trump]
# 43                              [Trump, FoxNews]
# 44                                       [Trump]
# 45                                         Trump
# 46                                          None
# 47                                  RushLimbaugh
# 48                                        Racist
# 49                                   Trumpspeech
# 50                                         Trump
# 51                                      Politics
# 52                                          None
# 53                                       [Trump]
# 54                                          EEUU
# 55                                       [Trump]
# 56                                 [impeachment]
# 57                                         Bigot
# 58                                 NeverTrumpers
# 59                                            []
# 60                                         Trump
# 61  [FunNFL, rannfl, nfl, nflmemes, donaldtrump]
# 62                                          None
# 63                                         Trump
# 64                                           Pig
# 65             [TrumpsGuilty, Trump, Tremendous]
# 66     [Trump, TheWhiteHouse, TheWashingtonPost]
# 67                                         Satan
# 68                           TrumpIsGuiltyPeriod
# 69                                       [Trump]
# 70                              Trump2020Victory
# 71                                PelosiMeltdown
# 72                                          None
# 73                                         Trump
# 74                                         Trump
# 75                                         bulls
# 76                                       kkkcult
# 77                                         Trump
# 78                                         Trump
# 79                                         Trump
# 80                                         Trump
# 81                                       GOPfail
# 82                                          None
# 83                                         trump
# 84                                          EEUU
# 85                                            []
# 86                                          None
#
